# %% [markdown]
# # 06 · Age sensitivity (Supplementary)
#
# Age-stratified baseline hazard and age-restricted (50–69) models.
#
# **Input:** `data/derived/imputed.parquet`
# **Output:** `output/tables/supp_age_sensitivity.tex`

# %%
import sys; sys.path.append('../src')
from utils import PATHS, extract_hr
import pandas as pd, numpy as np

# %%
# >>> PASTE your age-stratified + age-restricted 50–69 models code below. <<<
# ... your code ...
