# %% [markdown]
# # 03 · Consensus clustering → phenotypes
#
# Consensus clustering across base algorithms; relabel clusters to SIDD / MARD / SOIRD by their metabolic signature.
#
# **Input:** `data/derived/imputed.parquet`
# **Output:** `data/derived/clustered.parquet` (adds `phenotype`)

# %%
import sys; sys.path.append('../src')
from utils import PATHS, PHENOTYPE_ORDER, PHENOTYPE_COLORS
import pandas as pd, numpy as np

# %%
# >>> PASTE your consensus-clustering + relabelling code below. <<<
# ... your code ...
