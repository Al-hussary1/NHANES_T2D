# %% [markdown]
# # 01 · Derive analytic cohort
#
# Merge cycles, apply the type 2 diabetes definition, derive the phenotyping features (HbA1c, BMI, HOMA-IR, HOMA-B, age), apply inclusion/exclusion, attach mortality follow-up.
#
# **Input:** `data/raw/*`
# **Output:** `data/derived/cohort.parquet`

# %%
import sys; sys.path.append('../src')
from utils import PATHS
import pandas as pd, numpy as np

# %%
# >>> PASTE your cohort-derivation code below. <<<
# ... your code ...

# cohort.to_parquet(f"{PATHS['derived']}/cohort.parquet")
