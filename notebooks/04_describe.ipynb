# %% [markdown]
# # 04 · Table 1 — baseline characteristics
#
# **Input:** `data/derived/clustered.parquet`
# **Output:** `output/tables/table1_baseline.tex`

# %%
import sys; sys.path.append('../src')
from utils import PATHS
import pandas as pd, numpy as np

# %%
# >>> PASTE your Table 1 (median [IQR], Kruskal–Wallis; n(%), chi-square) code below. <<<
# ... your code ...
