# %% [markdown]
# # 05 · Primary Cox models (Table 3a / 3b)
#
# Progressive adjustment (unadjusted → +SES → +lifestyle) and the age-scale panel (no age → +age → attained-age timescale).
#
# **Input:** `data/derived/imputed.parquet`
# **Output:** `output/tables/table3_primary_hr.tex`, `table3_age_scale_hr.tex`

# %%
import sys; sys.path.append('../src')
from utils import PATHS, extract_hr, PHENOTYPE_ORDER
import pandas as pd, numpy as np
# from lifelines import CoxPHFitter

# %%
# >>> PASTE your primary Cox modelling (SPEC_FITTERS, plot_data) code below. <<<
# ... your code ...
