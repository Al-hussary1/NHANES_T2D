# %% [markdown]
# # 00 · Download NHANES data
#
# Fetch continuous NHANES cycles (1999–2018) and the NCHS Public-Use Linked Mortality Files into `data/raw/`.
#
# **Input:** none (pulls from CDC)
# **Output:** `data/raw/*` raw cycle and mortality files

# %%
import sys; sys.path.append('../src')
from utils import PATHS
import pandas as pd, numpy as np

# %%
# >>> PASTE your download code below. <<<
# e.g. loop over cycles with the `nhanes` package or pd.read_sas on XPT URLs
# save each retrieved file into PATHS['raw']
