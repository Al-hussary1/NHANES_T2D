# %% [markdown]
# # 07 · Figures
#
# Z-score heatmap, clinical radar, and the age-specification forest plot.
#
# **Input:** `data/derived/clustered.parquet`, model outputs from 05/06
# **Output:** `output/figures/*.png`

# %%
import sys; sys.path.append('../src')
from utils import PATHS, PHENOTYPE_COLORS, PHENOTYPE_ORDER, save_fig
import pandas as pd, numpy as np
import matplotlib.pyplot as plt

# %%
# >>> PASTE your figure code below. <<<
# heatmap / radar / forest — save with save_fig(fig, 'figNN_name')
