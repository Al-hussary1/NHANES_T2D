# %% [markdown]
# # 02 · Multiple imputation (MICE)
#
# **Input:** `data/derived/cohort.parquet`
# **Output:** `data/derived/imputed.parquet` (stacked imputations, `.imp` column)

# %%
import sys; sys.path.append('../src')
from utils import PATHS
import pandas as pd, numpy as np
# from sklearn.experimental import enable_iterative_imputer  # noqa
# from sklearn.impute import IterativeImputer
# or: import miceforest as mf   (closer to R's mice)

# %%
# >>> PASTE your MICE imputation (m, method, random_state) code below. <<<
# ... your code ...
